# %%
import pandas as pd

# %% [markdown]
# #### Reading CSV File

# %%
pd.read_csv(r"C:\Users\Bilal Home\Documents\Projects\Pandas-A-python-library\Dataset\world_population.csv")
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# Header are defined with the data when we read the file but if if don't want header we can elminate them by command header = None

# %%
pd.read_csv(r"C:\Users\Bilal Home\Documents\Projects\Pandas-A-python-library\Dataset\world_population.csv", header = None)
# Out:
#        0     1                  2          3          4                5   \
# 0    Rank  CCA3  Country/Territory    Capital  Continent  2022 Population
# 1      36   AFG        Afghanistan      Kabul       Asia         41128771
# 2     138   ALB            Albania     Tirana     Europe          2842321
# 3      34   DZA            Algeria    Algiers     Africa         44903225
# 4     213   ASM     American Samoa  Pago Pago    Oceania            44273
# ..    ...   ...                ...        ...        ...              ...
# 230   226   WLF  Wallis and Futuna   Mata-Utu    Oceania            11572
# 231   172   ESH     Western Sahara   El Aaiún     Africa           575986
# 232    46   YEM              Yemen      Sanaa       Asia         33696614
# 233    63   ZMB             Zambia     Lusaka     Africa         20017675
# 234    74   ZWE           Zimbabwe     Harare     Africa         16320537
#
#                   6                7                8                9   \
# ...

# %%
df = pd.read_csv(r"C:\Users\Bilal Home\Documents\Projects\Pandas-A-python-library\Dataset\world_population.csv")

# %%
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# #### Reading Json File

# %%
df2 = pd.read_json(r"C:\Users\Bilal Home\Documents\Projects\Pandas-A-python-library\Dataset\employees.json")
df2
# Out:
#                                            Employees
# 0  {'userId': 'rirani', 'jobTitleName': 'Develope...
# 1  {'userId': 'nirani', 'jobTitleName': 'Develope...
# 2  {'userId': 'thanks', 'jobTitleName': 'Program ...

# %% [markdown]
# #### Reading Excel File

# %%
df3 = pd.read_excel(r"C:\Users\Bilal Home\Documents\Projects\Pandas-A-python-library\Dataset\sampledataworkorders.xlsx")
df3
# Out:
#          WO   District LeadTech  Service Rush    ReqDate   WorkDate  Techs  \
# 0    A00100      North     Khan   Assess  NaN 2020-09-01 2020-09-15      2
# 1    A00101      South    Lopez  Replace  NaN 2020-09-01 2020-09-04      1
# 2    A00102    Central  Cartier  Deliver  NaN 2020-09-01 2020-09-17      1
# 3    A00103      South    Lopez  Deliver  NaN 2020-09-01 2020-09-17      1
# 4    A00104  Northwest  Cartier  Deliver  Yes 2020-09-01 2020-09-17      1
# ..      ...        ...      ...      ...  ...        ...        ...    ...
# 995  A01095  Southeast   Burton   Assess  NaN 2021-07-22        NaT      2
# 996  A01096  Northwest  Cartier   Repair  NaN 2021-07-22        NaT      1
# 997  A01097    Central  Cartier   Assess  NaN 2021-07-23        NaT      1
# 998  A01098       East     Ling  Deliver  NaN 2021-07-24        NaT      1
# 999  A01100       East     Ling   Assess  NaN 2021-07-29        NaT      2
#
# ...

# %%
df3.info() # it will show the column name, datatype of the column and Nul count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   WO         1000 non-null   object
#  1   District   1000 non-null   object
#  2   LeadTech   1000 non-null   object
#  3   Service    1000 non-null   object
#  4   Rush       103 non-null    object
#  5   ReqDate    1000 non-null   datetime64[ns]
#  6   WorkDate   858 non-null    datetime64[ns]
#  7   Techs      1000 non-null   int64
#  8   WtyLbr     41 non-null     object
#  9   WtyParts   94 non-null     object
#  10  LbrHrs     858 non-null    float64
#  11  PartsCost  1000 non-null   float64
#  12  Payment    1000 non-null   object
#  13  Wait       858 non-null    float64
#  14  LbrRate    1000 non-null   int64
#  15  LbrCost    1000 non-null   float64
#  16  LbrFee     1000 non-null   float64
#  17  PartsFee   1000 non-null   float64
#  18  TotalCost  1000 non-null   float64
# ...

# %%
df3.shape # it will show how many rows and columns we have in our dataset
# Out:
# (1000, 22)

# %%
df.head() # it will give first 5 values
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.head(10) # we can specify the number of rows we want by giging the number
# Out:
#    Rank CCA3    Country/Territory           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# 1          2842321          2866849          2882481          2913399
# ...

# %%
df3.tail(10) # The last 10 rows
# Out:
#          WO   District LeadTech  Service Rush    ReqDate WorkDate  Techs  \
# 990  A01090      North     Ling  Replace  NaN 2021-07-21      NaT      2
# 991  A01091  Northwest  Cartier  Replace  NaN 2021-07-21      NaT      2
# 992  A01092  Northwest  Cartier   Assess  Yes 2021-07-22      NaT      2
# 993  A01093  Northwest     Khan   Repair  NaN 2021-07-22      NaT      1
# 994  A01094  Southeast  Cartier   Assess  NaN 2021-07-22      NaT      1
# 995  A01095  Southeast   Burton   Assess  NaN 2021-07-22      NaT      2
# 996  A01096  Northwest  Cartier   Repair  NaN 2021-07-22      NaT      1
# 997  A01097    Central  Cartier   Assess  NaN 2021-07-23      NaT      1
# 998  A01098       East     Ling  Deliver  NaN 2021-07-24      NaT      1
# 999  A01100       East     Ling   Assess  NaN 2021-07-29      NaT      2
#
#     WtyLbr WtyParts  ...  Payment  Wait LbrRate  LbrCost  LbrFee  PartsFee  \
# 990    NaN      NaN  ...  Account   NaN     140      0.0     0.0   21.3300
# ...

# %%
df3.loc[102]
# Out:
# WO                        A00202
# District                 Central
# LeadTech                  Burton
# Service                   Repair
# Rush                         NaN
# ReqDate      2020-10-14 00:00:00
# WorkDate     2020-11-03 00:00:00
# Techs                          2
# WtyLbr                       NaN
# WtyParts                     NaN
# LbrHrs                       2.0
# PartsCost               619.5133
# Payment                     P.O.
# Wait                        20.0
# LbrRate                      140
# LbrCost                    280.0
# LbrFee                     280.0
# PartsFee                619.5133
# TotalCost               899.5133
# TotalFee                899.5133
# ReqDay                       Wed
# WorkDay                      Tue
# Name: 102, dtype: object

# %%
df3.iloc[102]
# Out:
# WO                        A00202
# District                 Central
# LeadTech                  Burton
# Service                   Repair
# Rush                         NaN
# ReqDate      2020-10-14 00:00:00
# WorkDate     2020-11-03 00:00:00
# Techs                          2
# WtyLbr                       NaN
# WtyParts                     NaN
# LbrHrs                       2.0
# PartsCost               619.5133
# Payment                     P.O.
# Wait                        20.0
# LbrRate                      140
# LbrCost                    280.0
# LbrFee                     280.0
# PartsFee                619.5133
# TotalCost               899.5133
# TotalFee                899.5133
# ReqDay                       Wed
# WorkDay                      Tue
# Name: 102, dtype: object
